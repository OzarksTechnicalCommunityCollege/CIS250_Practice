-- %% [markdown]
-- # CIS 250- Practice Assignment
-- Great work cloning your repository and opening the starter file! If you are reading this on Github, go back tot he ReadMe file and make sure you read the instructions carefully. <br>
-- To complete this assignment:
-- * Add a new _text_ cell using the "+ Cell" button above.
-- * Inside the new cell, type "Hello, Github!". <br>
-- Once done, save your changes and refer back to the _Turning in Assignments Using Github_ instructions in Canvas to complete your submission.
